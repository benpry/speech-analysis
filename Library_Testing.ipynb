# %%
# !pip install --upgrade numpy
# !pip install --upgrade gensim
# !pip install --upgrade nltk
# !pip install --upgrade empath
# Out:
# Collecting numpy
#   Downloading https://files.pythonhosted.org/packages/fb/7d/f8b97d97809f184d90faf320fa8e2e7eac994844c5e6c57adbed1283e9e9/numpy-1.15.1-cp36-none-win_amd64.whl (13.5MB)
# Installing collected packages: numpy
#   Found existing installation: numpy 1.14.3
#     Uninstalling numpy-1.14.3:
#       Successfully uninstalled numpy-1.14.3
# Successfully installed numpy-1.15.1
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Collecting gensim
#   Downloading https://files.pythonhosted.org/packages/a9/78/7f51f0d83f23ced1a951aa9db5873829d9b03ac351dcdb3e7c4d5f002c0d/gensim-3.5.0-cp36-cp36m-win_amd64.whl (23.5MB)
# Requirement not upgraded as not directly required: scipy>=0.18.1 in c:\users\bprys\anaconda3\lib\site-packages (from gensim) (1.1.0)
# Collecting smart-open>=1.2.1 (from gensim)
#   Downloading https://files.pythonhosted.org/packages/cf/3d/5f3a9a296d0ba8e00e263a8dee76762076b9eb5ddc254ccaa834651c8d65/smart_open-1.6.0.tar.gz
# Requirement not upgraded as not directly required: six>=1.5.0 in c:\users\bprys\anaconda3\lib\site-packages (from gensim) (1.11.0)
# Requirement not upgraded as not directly required: numpy>=1.11.3 in c:\users\bprys\anaconda3\lib\site-packages (from gensim) (1.15.1)
# Requirement not upgraded as not directly required: boto>=2.32 in c:\users\bprys\anaconda3\lib\site-packages (from smart-open>=1.2.1->gensim) (2.48.0)
# Collecting bz2file (from smart-open>=1.2.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/61/39/122222b5e85cd41c391b68a99ee296584b2a2d1d233e7ee32b4532384f2d/bz2file-0.98.tar.gz
# Requirement not upgraded as not directly required: requests in c:\users\bprys\anaconda3\lib\site-packages (from smart-open>=1.2.1->gensim) (2.18.4)
# Collecting boto3 (from smart-open>=1.2.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/45/05/f5f4610cab8c76d102f607a05b0f86d0525c52e72b484dfd9f65af86e0a4/boto3-1.9.4-py2.py3-none-any.whl (128kB)
# Requirement not upgraded as not directly required: chardet<3.1.0,>=3.0.2 in c:\users\bprys\anaconda3\lib\site-packages (from requests->smart-open>=1.2.1->gensim) (3.0.4)
# Requirement not upgraded as not directly required: idna<2.7,>=2.5 in c:\users\bprys\anaconda3\lib\site-packages (from requests->smart-open>=1.2.1->gensim) (2.6)
# Requirement not upgraded as not directly required: urllib3<1.23,>=1.21.1 in c:\users\bprys\anaconda3\lib\site-packages (from requests->smart-open>=1.2.1->gensim) (1.22)
# Requirement not upgraded as not directly required: certifi>=2017.4.17 in c:\users\bprys\anaconda3\lib\site-packages (from requests->smart-open>=1.2.1->gensim) (2018.4.16)
# Collecting jmespath<1.0.0,>=0.7.1 (from boto3->smart-open>=1.2.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/b7/31/05c8d001f7f87f0f07289a5fc0fc3832e9a57f2dbd4d3b0fee70e0d51365/jmespath-0.9.3-py2.py3-none-any.whl
# Collecting s3transfer<0.2.0,>=0.1.10 (from boto3->smart-open>=1.2.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/d7/14/2a0004d487464d120c9fb85313a75cd3d71a7506955be458eebfe19a6b1d/s3transfer-0.1.13-py2.py3-none-any.whl (59kB)
# Collecting botocore<1.13.0,>=1.12.4 (from boto3->smart-open>=1.2.1->gensim)
#   Downloading https://files.pythonhosted.org/packages/c1/3d/32145d948eea4a41aadd678e681671d0f275ad1b2713b5c54307800d1fe2/botocore-1.12.4-py2.py3-none-any.whl (4.7MB)
# Requirement not upgraded as not directly required: python-dateutil<3.0.0,>=2.1; python_version >= "2.7" in c:\users\bprys\anaconda3\lib\site-packages (from botocore<1.13.0,>=1.12.4->boto3->smart-open>=1.2.1->gensim) (2.7.3)
# Requirement not upgraded as not directly required: docutils>=0.10 in c:\users\bprys\anaconda3\lib\site-packages (from botocore<1.13.0,>=1.12.4->boto3->smart-open>=1.2.1->gensim) (0.14)
# Building wheels for collected packages: smart-open, bz2file
#   Running setup.py bdist_wheel for smart-open: started
#   Running setup.py bdist_wheel for smart-open: finished with status 'done'
#   Stored in directory: C:\Users\bprys\AppData\Local\pip\Cache\wheels\73\f1\9b\ccf93d4ba073b6f79b1ed9df68ab5ce048d8136d0efcf90b30
#   Running setup.py bdist_wheel for bz2file: started
#   Running setup.py bdist_wheel for bz2file: finished with status 'done'
#   Stored in directory: C:\Users\bprys\AppData\Local\pip\Cache\wheels\81\75\d6\e1317bf09bf1af5a30befc2a007869fa6e1f516b8f7c591cb9
# Successfully built smart-open bz2file
# Installing collected packages: bz2file, jmespath, botocore, s3transfer, boto3, smart-open, gensim
# Successfully installed boto3-1.9.4 botocore-1.12.4 bz2file-0.98 gensim-3.5.0 jmespath-0.9.3 s3transfer-0.1.13 smart-open-1.6.0
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Requirement already up-to-date: nltk in c:\users\bprys\anaconda3\lib\site-packages (3.3)
# Requirement not upgraded as not directly required: six in c:\users\bprys\anaconda3\lib\site-packages (from nltk) (1.11.0)
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Collecting empath
#   Downloading https://files.pythonhosted.org/packages/d2/84/a5de61a99252f60d705d7982b3648db517a704c89fa7629d3d3637a6e604/empath-0.89.tar.gz (57kB)
# Requirement not upgraded as not directly required: requests in c:\users\bprys\anaconda3\lib\site-packages (from empath) (2.18.4)
# Requirement not upgraded as not directly required: chardet<3.1.0,>=3.0.2 in c:\users\bprys\anaconda3\lib\site-packages (from requests->empath) (3.0.4)
# Requirement not upgraded as not directly required: idna<2.7,>=2.5 in c:\users\bprys\anaconda3\lib\site-packages (from requests->empath) (2.6)
# Requirement not upgraded as not directly required: urllib3<1.23,>=1.21.1 in c:\users\bprys\anaconda3\lib\site-packages (from requests->empath) (1.22)
# Requirement not upgraded as not directly required: certifi>=2017.4.17 in c:\users\bprys\anaconda3\lib\site-packages (from requests->empath) (2018.4.16)
# Building wheels for collected packages: empath
#   Running setup.py bdist_wheel for empath: started
#   Running setup.py bdist_wheel for empath: finished with status 'done'
#   Stored in directory: C:\Users\bprys\AppData\Local\pip\Cache\wheels\84\ea\2f\2bc54d4f9985ce61753ebc5b00cb2df51d855589267c667308
# Successfully built empath
# Installing collected packages: empath
# Successfully installed empath-0.89
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import gensim as gs
import nltk
from empath import Empath
# Out:
# C:\Users\bprys\Anaconda3\lib\site-packages\gensim\utils.py:1209: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
lexicon = Empath()

# %%
to_analyze = """My fellow citizens:  I stand here today humbled by the task before us, grateful for the trust you've bestowed, mindful of the sacrifices borne by our ancestors. 
 
I thank President Bush for his service to our nation -- (applause) -- as well as the generosity and cooperation he has shown throughout this transition.
 
Forty-four Americans have now taken the presidential oath.  The words have been spoken during rising tides of prosperity and the still waters of peace.  Yet, every so often, the oath is taken amidst gathering clouds and raging storms.  At these moments, America has carried on not simply because of the skill or vision of those in high office, but because we, the people, have remained faithful to the ideals of our forebears and true to our founding documents. 
 
So it has been; so it must be with this generation of Americans.
 
That we are in the midst of crisis is now well understood.  Our nation is at war against a far-reaching network of violence and hatred.  Our economy is badly weakened, a consequence of greed and irresponsibility on the part of some, but also our collective failure to make hard choices and prepare the nation for a new age.  Homes have been lost, jobs shed, businesses shuttered.  Our health care is too costly, our schools fail too many -- and each day brings further evidence that the ways we use energy strengthen our adversaries and threaten our planet.

These are the indicators of crisis, subject to data and statistics.  Less measurable, but no less profound, is a sapping of confidence across our land; a nagging fear that America's decline is inevitable, that the next generation must lower its sights.
 
Today I say to you that the challenges we face are real.  They are serious and they are many.  They will not be met easily or in a short span of time.  But know this America:  They will be met.  (Applause.)
 
On this day, we gather because we have chosen hope over fear, unity of purpose over conflict and discord.  On this day, we come to proclaim an end to the petty grievances and false promises, the recriminations and worn-out dogmas that for far too long have strangled our politics.  We remain a young nation.  But in the words of Scripture, the time has come to set aside childish things.  The time has come to reaffirm our enduring spirit; to choose our better history; to carry forward that precious gift, that noble idea passed on from generation to generation:  the God-given promise that all are equal, all are free, and all deserve a chance to pursue their full measure of happiness.  (Applause.)
 
In reaffirming the greatness of our nation we understand that greatness is never a given.  It must be earned.  Our journey has never been one of short-cuts or settling for less.  It has not been the path for the faint-hearted, for those that prefer leisure over work, or seek only the pleasures of riches and fame.  Rather, it has been the risk-takers, the doers, the makers of things -- some celebrated, but more often men and women obscure in their labor -- who have carried us up the long rugged path towards prosperity and freedom. 
 
Thank you.  God bless you.  And God bless the United States of America."""

# %%
results = lexicon.analyze(to_analyze)

# %%
output = sorted(results, key=results.get, reverse=True)

# %%
output
# Out:
# ['optimism',
#  'positive_emotion',
#  'strength',
#  'power',
#  'government',
#  'speaking',
#  'royalty',
#  'trust',
#  'divine',
#  'children',
#  'business',
#  'achievement',
#  'negative_emotion',
#  'politics',
#  'terrorism',
#  'healing',
#  'military',
#  'communication',
#  'fight',
#  'gain',
#  'economics',
#  'giving',
#  'help',
#  'traveling',
#  'sadness',
#  'wedding',
#  'pride',
#  'leader',
#  'deception',
#  'shape_and_size',
#  'party',
#  'poor',
#  'family',
#  'suffering',
#  'movement',
#  'confusion',
#  'legend',
#  'heroic',
#  'war',
#  'cold',
#  'aggression',
#  'vacation',
#  'magic',
#  'banking',
#  'love',
#  'hiking',
#  'weather',
#  'ancient',
#  'air_travel',
#  'meeting',
#  'shame',
#  'friends',
#  'dispute',
#  'leisure',
#  'religion',
#  'worship',
#  'body',
#  'celebration',
#  'violence',
#  'dominant_heirarchical',
#  'politeness',
#  'work',
#  'valuable',
#  'technology',
#  'pain',
#  'law',
#  'medical_emergency',
#  'occupation',
#  'crime',
#  'stealing',
#  'home',
#  'fear',
#  'surprise',
#  'death',
#  'neglect',
#  'toy',
#  'shopping',
#  'phone',
#  'affection',
#  'philosophy',
#  'messaging',
#  'hate',
#  'envy',
#  'masculine',
#  'school',
#  'play',
#  'eating',
#  'programming',
#  'order',
#  'sympathy',
#  'disgust',
#  'injury',
#  'rage',
#  'science',
#  'appearance',
#  'warmth',
#  'youth',
#  'fun',
#  'torment',
#  'competing',
#  'contentment',
#  'money',
#  'domestic_work',
#  'cheerfulness',
#  'prison',
#  'health',
#  'nervousness',
#  'horror',
#  'wealthy',
#  'tourism',
#  'beach',
#  'morning',
#  'social_media',
#  'kill',
#  'blue_collar_job',
#  'ridicule',
#  'computer',
#  'college',
#  'real_estate',
#  'driving',
#  'pet',
#  'exasperation',
#  'internet',
#  'reading',
#  'independence',
#  'medieval',
#  'water',
#  'exotic',
#  'music',
#  'listen',
#  'fire',
#  'emotional',
#  'joy',
#  'fashion',
#  'anger',
#  'breaking',
#  'white_collar_job',
#  'animal',
#  'smell',
#  'beauty',
#  'negotiate',
#  'cleaning',
#  'weapon',
#  'rural',
#  'musical',
#  'dance',
#  'sleep',
#  'weakness',
#  'swearing_terms',
#  'night',
#  'art',
#  'sexual',
#  'childish',
#  'cooking',
#  'noise',
#  'zest',
#  'sports',
#  'restaurant',
#  'hearing',
#  'hygiene',
#  'fabric',
#  'urban',
#  'tool',
#  'sailing',
#  'ugliness',
#  'lust',
#  'disappointment',
#  'plant',
#  'timidity',
#  'payment',
#  'liquid',
#  'feminine',
#  'monster',
#  'ocean',
#  'writing',
#  'office',
#  'anticipation',
#  'attractive',
#  'furniture',
#  'journalism',
#  'exercise',
#  'irritability',
#  'superhero',
#  'hipster',
#  'swimming',
#  'anonymity',
#  'dominant_personality',
#  'vehicle',
#  'farming',
#  'sound',
#  'ship',
#  'clothing',
#  'car',
#  'alcohol']
